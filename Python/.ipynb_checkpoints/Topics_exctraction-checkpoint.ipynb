# %% [markdown]
# # Extraction of topics from Wikipedia pages

# %%
import numpy as np
import networkx as nx
import requests
import pandas as pd
import csv
import matplotlib.pyplot as plt

# %%
### Importation of the Graph from gexf file ###

Graph = nx.read_gexf("peaks_graph_mod.gexf") 


### Creating Pandas DataFrame from Graph for convenient access ###

dataFrame = pd.DataFrame.from_dict(dict(Graph.nodes(data=True)), orient='index')
dataFrame['Qid'] = ''
dataFrame['topic'] = ''
dataFrame['probability'] = ''
dataFrame = dataFrame[['Qid', 'label', 'topic', 'probability', 'Modularity Class']]
print(dataFrame.info())
dataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4604 entries, 55232472 to 346783
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Qid               4604 non-null   object
#  1   label             4604 non-null   object
#  2   topic             4604 non-null   object
#  3   probability       4604 non-null   object
#  4   Modularity Class  4604 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 215.8+ KB
# None
#          Qid                                              label topic  \
# 55232472                                        2019_CFL_season
# 3946242                                      Eimuntas_Nekro?ius
# 8161118                     Bobby_Carpenter_(American_football)
# 51544610                                       Florence_Kasumba
# 692976                                     Beorhtwulf_of_Mercia
# ...       ..                                                ...   ...
# ...

# %%
### Extract nodes labels from Wikipedia queries ###


# Find the key of the value 'kv'  in a nested dictionnary
def findkeys(node, kv):
    if isinstance(node, list):
        for i in node:
            for x in findkeys(i, kv):
               yield x
    elif isinstance(node, dict):
        if kv in node:
            yield node[kv]
        for j in node.values():
            for x in findkeys(j, kv):
                yield x

            


# URL for the quieries
urls = "https://en.wikipedia.org/w/api.php?action=query&prop=pageprops&format=json&pageids="


i=0
Nb_pages = len(dataFrame)


### Associate the 'Qid' value of Wikipedia pages in the DataFrame ###
### Give '-1' value if an error has occured during the query      ###

for pageId in dataFrame.index:
    response = requests.get(urls + pageId).json()
    try:
        Qid = (list(findkeys(response, 'wikibase_item'))[0])
    except IndexError:
        dataFrame.loc[pageId, 'Qid'] = '-1'
        i+=1
        print(i,"/", Nb_pages, dataFrame.loc[pageId, 'label'], "   error")
    else:
        dataFrame.loc[pageId, 'Qid'] = Qid
        i+=1
        print(i,"/", Nb_pages, dataFrame.loc[pageId, 'label'])

        
# Save the DataFrame with their associated Qids
dataFrame.to_csv('pages_Qids.csv', encoding='utf-8')

# %%
# ### Extract topic for each Wikipedia page from the DataBase containing all topics of Wikipedia pages ###

# dataFrame = pd.read_csv('pages_Qids.csv')

# # Creating new DataFrame with identic labels as the DataBase
# Match_topic = pd.DataFrame(columns = ['Qid', 'topic', 'probability', 'page_id', 'page_title', 'wiki_db'])


# # Since the DataBase is huge, we read 10^6 pages at a time 
# chunksize = 10 ** 6


# ### Matching Qids from DataFrame to DataBase and finding their corresponding Topics,  ###
# ### Probabilties, Languages and appending then with their Modularity Class.           ###
# ### This process takes hours to compute due to the huge Database... try to be patient ###

# for chunk in pd.read_csv('topicsForAllWikipediaPages.csv', chunksize=chunksize, error_bad_lines=False):
#     chunk_page_Qid = list(chunk['Qid'])
#     for pageQid in list(dataFrame['Qid']):
#         if (pageQid in chunk_page_Qid):
#             page = chunk.loc[((chunk['Qid'] == pageQid) & (chunk['wiki_db'] == 'enwiki'))]
#             mod_class = dataFrame.loc[dataFrame['Qid'] == pageQid, 'Modularity Class'].values[0]
#             page = page.assign(Modularity_Class = mod_class)
#             Match_topic = Match_topic.append(page, ignore_index=True)
                   

# # Save the DataFrame with their associated Qids, Topics
# Match_topic.to_csv('Match_topic.csv', encoding='utf-8')

# # Display the DataFrame
# Match_topic
# Out:
# b'Skipping line 153592: expected 6 fields, saw 7\nSkipping line 153593: expected 6 fields, saw 7\nSkipping line 186030: expected 6 fields, saw 8\nSkipping line 186031: expected 6 fields, saw 8\nSkipping line 186032: expected 6 fields, saw 8\nSkipping line 186033: expected 6 fields, saw 8\nSkipping line 186034: expected 6 fields, saw 8\nSkipping line 186035: expected 6 fields, saw 8\n'
# b'Skipping line 410306: expected 6 fields, saw 7\nSkipping line 410307: expected 6 fields, saw 7\n'
# b'Skipping line 643471: expected 6 fields, saw 7\nSkipping line 643472: expected 6 fields, saw 7\n'
# ...

# %%
### Extract topic for each Wikipedia page from the DataBase containing all topics of Wikipedia pages ###


dataFrame = pd.read_csv('pages_Qids.csv', index_col = 'Unnamed: 0')

Match_topic_API = pd.DataFrame(columns = ['Qid', 'topic', 'probability', 'page_id', 'page_title', 'modularity_class', 'wiki_db'])

def findkeys(node, kv):
    if isinstance(node, list):
        for i in node:
            for x in findkeys(i, kv):
               yield x
    elif isinstance(node, dict):
        if kv in node:
            yield node[kv]
        for j in node.values():
            for x in findkeys(j, kv):
                yield x
                
                
                
urls = "http://86.119.25.229:5000/api/v1/wikidata/topic?qid="
threshold = '0.1'

    
tmps1=time.time()
    
a=0    
for pageIndex in dataFrame.index:
    pageQid = dataFrame.at[pageIndex, 'Qid']
    pageModularity = dataFrame.at[pageIndex, 'Modularity Class']
    response = requests.get(urls + pageQid + "&threshold=" + threshold).json()
    scores = list(findkeys(response, 'score'))
    topics = list(findkeys(response, 'topic'))
    
    try:
        page_title = response['name']
    except KeyError:
        page_title = dataFrame.at[pageIndex, 'label']
    for i in range(len(scores)):
        page = pd.DataFrame({'Qid':[pageQid], 'topic':[topics[i]], 'page_id':[pageIndex], 'probability':[scores[i]], 'page_title':[page_title], 'modularity_class':[pageModularity],'wiki_db':['enwiki'] })
        Match_topic_API = Match_topic_API.append(page, ignore_index=True)
    print(a, "/4604")
    a+=1

tmps2=time.time()
print("Temps d'execution = ",(tmps2-tmps1), " s")


Match_topic_API.to_csv('Match_topic_API.csv', encoding='utf-8')

Match_topic_API

# %%
### Helps to find the most frequent topic of each clusted based on modularity ###

dataFrame = pd.read_csv('Match_topic.csv', index_col = 'page_id')


# Counting the number of repeated topics and sorting them 
topic_group = ((dataFrame.groupby(['topic', 'Modularity_Class']))).count()

topic_group = topic_group['Qid'].to_frame().reset_index('topic')
topic_group.rename(columns={'Qid':'Count'}, inplace=True)

topic_group.sort_values(by = ['Modularity_Class', 'Count'], inplace=True, ascending = [True, False])
topic_group.to_csv('topics_counting.csv', encoding='utf-8')



### Thresholding and deleting Biography ###
threshold = 15
cluster = 9  # from 0 to 12

topic_group = topic_group.loc[topic_group['topic'] != 'Culture.Biography.Biography*']
topic_group = topic_group.loc[topic_group['Count'] > threshold]
print(topic_group.loc[cluster])
# Out:
#                                                         topic  Count
# Modularity_Class
# 9.0                  Geography.Regions.Americas.North_America    262
# 9.0               History_and_Society.Politics_and_government    116
# 9.0                                      Culture.Media.Media*     96
# 9.0                               History_and_Society.Society     53
# 9.0                              Geography.Regions.Asia.Asia*     42
# 9.0                                                STEM.STEM*     33
# 9.0                                   Culture.Biography.Women     30
# 9.0                          Geography.Regions.Asia.East_Asia     27
# 9.0                                  Culture.Media.Television     26
# 9.0                                        Culture.Literature     23
# 9.0                                    Geography.Geographical     23
# 9.0                                       Culture.Media.Films     22
# ...

# %%
### Labelling "by hand" all clusters based on most counted topics ###

dataFrame = pd.read_csv('Match_topic.csv', index_col = 'page_id')


dataFrame.loc[dataFrame['Modularity_Class'] == 0, 'Label'] = 'Irish Rubgy Championship' 
dataFrame.loc[dataFrame['Modularity_Class'] == 1, 'Label'] = '~~News Items~~' 
dataFrame.loc[dataFrame['Modularity_Class'] == 2, 'Label'] = 'Canadian Football' 
    dataFrame.loc[dataFrame['Modularity_Class'] == 3, 'Label'] = 'The Lion King Announcement'   
dataFrame.loc[dataFrame['Modularity_Class'] == 4, 'Label'] = 'Viking (in England)*'     
dataFrame.loc[dataFrame['Modularity_Class'] == 5, 'Label'] = 'Cambodian Genocide Sentence' 
dataFrame.loc[dataFrame['Modularity_Class'] == 6, 'Label'] = 'Ukraine'   
dataFrame.loc[dataFrame['Modularity_Class'] == 7, 'Label'] = 'Killing in Andaman Islands '  
dataFrame.loc[dataFrame['Modularity_Class'] == 8, 'Label'] = 'Space missions'   
dataFrame.loc[dataFrame['Modularity_Class'] == 9, 'Label'] = 'Midterm US election'  
dataFrame.loc[dataFrame['Modularity_Class'] == 10, 'Label'] = 'Victoria election (Autralia)'   
dataFrame.loc[dataFrame['Modularity_Class'] == 11, 'Label'] = 'Football'  
dataFrame.loc[dataFrame['Modularity_Class'] == 12, 'Label'] = 'Bernardo Bertolucci death'    



dataFrame = dataFrame.drop(columns = ['Unnamed: 0'] )
dataFrame.rename(columns={'Modularity_Class':'Modularity Class'}, inplace=True)
dataFrame.index.rename('Id', inplace=True)
dataFrame.to_csv('page_label.csv', encoding='utf-8')
dataFrame
# Out:
#                 Qid                                       topic  probability  \
# Id
# 10602046  Q15628924                              Culture.Sports         0.93
# 9895126     Q109193                Culture.Biography.Biography*         0.99
# 9895126     Q109193                        Culture.Media.Media*         0.52
# 10819298   Q4076739    Geography.Regions.Europe.Northern_Europe         1.00
# 10819298   Q4076739            Geography.Regions.Europe.Europe*         1.00
# ...             ...                                         ...          ...
# 1602443    Q7287957                Culture.Biography.Biography*         1.00
# 1602443    Q7287957    Geography.Regions.Americas.North_America         0.89
# 57255955  Q54871436                              Culture.Sports         1.00
# 23699941   Q6662391                Culture.Biography.Biography*         1.00
# 23699941   Q6662391  History_and_Society.Business_and_economics         0.67
#
# ...

# %%
import numpy as np
import networkx as nx
import requests
import pandas as pd
import csv
import matplotlib.pyplot as plt
import time

### src countains Qid, Topic, Probability, Page Id, Wiki_DB ###
src = pd.read_csv('Match_topic_API.csv')

### dst countains modularity_class, clusters ##
dst = pd.read_csv('nodes.csv')




def change_modularity(src, dst):
    src['modularity_class'] = ''
    src['cluster'] = ''
    for page_index in dst['Id']:
        src.loc[src['page_id'] == page_index, 'modularity_class'] = dst.loc[dst['Id'] == page_index, 'modularity_class'].item()
        src.loc[src['page_id'] == page_index, 'cluster'] = dst.loc[dst['Id'] == page_index, 'Cluster'].item()
        src.loc[src['page_id'] == page_index, 'degree'] = dst.loc[dst['Id'] == page_index, 'Degree'].item()
    return src

changed_modularity = change_modularity(src, dst)

changed_modularity.to_csv('page_cluster.csv', encoding='utf-8')

changed_modularity

# %%
import numpy as np
import networkx as nx
import requests
import pandas as pd
import csv
import matplotlib.pyplot as plt




def string_separator(df):
    for index, row in df.iterrows():
        topic_str = row['topic']
        topic_list = topic_str.split('.') 
        df.loc[df['topic'] == topic_str, 'subtopic'] = topic_list[-1]

        



dataFrame = pd.read_csv('page_cluster.csv')
dataFrame.drop(columns = ['Unnamed: 0.1', 'Unnamed: 0'], inplace = True )










def find_main_topics_clusters(cluster_name, dataFrame, modularity_df):
    
    dataFrame_without_biography = dataFrame.loc[dataFrame['topic'] != 'Culture.Biography.Biography*']

    topic_group = ((dataFrame_without_biography.groupby(['topic', cluster_name]))).count()


    total_cluster = ((dataFrame_without_biography.groupby([cluster_name]))).count()
    total_cluster = total_cluster['Qid'].to_frame()
    total_cluster.rename(columns={'Qid':'total'}, inplace=True)

    topic_group = topic_group['Qid'].to_frame().reset_index('topic')
    topic_group.rename(columns={'Qid':'count'}, inplace=True)
    topic_group.sort_values(by = [cluster_name, 'count'], inplace=True, ascending = [True, False])

    topic_group['total'] = total_cluster['total']
    topic_group['ratio'] = topic_group['count'] / topic_group['total']
    topic_group['subtopic'] = ''
    string_separator(topic_group)


#    topic_group = topic_group.loc[ (topic_group['total'] > 0) & (topic_group['ratio'] > 0.05) ]

    nb_topic = dataFrame[cluster_name].max() + 1
    for i in range(nb_topic):
        str_main_topics = topic_group.loc[i, 'subtopic'].values[0] + ' (' + str((topic_group.loc[i, 'ratio'].values[0]).round(decimals=2)) + ') '
        str_main_topics += '/ ' + topic_group.loc[i, 'subtopic'].values[1] + ' (' + str((topic_group.loc[i, 'ratio'].values[1]).round(decimals=2)) + ') '
        str_main_topics += '/ ' + topic_group.loc[i, 'subtopic'].values[2] + ' (' + str((topic_group.loc[i, 'ratio'].values[2]).round(decimals=2)) + ') '
        dataFrame.loc[dataFrame[cluster_name] == i, (cluster_name+'_topic')] = str_main_topics
        
        page_id_max_degree = dataFrame.loc[dataFrame[cluster_name] == i, 'degree'].idxmax()
        str_degree = dataFrame.loc[page_id_max_degree, 'page_title'] + ' (' + str(int(dataFrame.loc[page_id_max_degree, 'degree'])) + ')'
        
        mod = {'main_topics':str_main_topics, 'higher_degree_article':str_degree}
        modularity_df = modularity_df.append(mod, ignore_index=True)
        
    return modularity_df
cluster_name = 'modularity_class'   

modularity_df = pd.DataFrame({'main_topics':[], 'higher_degree_article':[]})


# dataFrame.loc[dataFrame[cluster_name] == 5, 'degree'].idxmax()
# dataFrame.loc[228]

modularity_df = find_main_topics_clusters(cluster_name, dataFrame, modularity_df) 
# cluster_name = 'cluster'      
# find_main_topics_clusters(cluster_name, dataFrame) 

modularity_df.index.rename('modularity_class', inplace = True)

modularity_df.to_csv('modularity_topics.csv', encoding='utf-8')

modularity_df
# Out:
#                                                         main_topics  \
# modularity_class
# 0                 Sports (0.47) / Europe* (0.22) / Northern_Euro...
# 1                 Europe* (0.15) / Northern_Europe (0.15) / Poli...
# 2                 Media* (0.28) / Films (0.16) / North_America (...
# 3                 North_America (0.31) / Politics_and_government...
# 4                 Media* (0.23) / Films (0.17) / North_America (...
# 5                 Asia* (0.22) / South_Asia (0.16) / Geographica...
# 6                      Media* (0.24) / Films (0.21) / Asia* (0.11)
# 7                  STEM* (0.42) / Space (0.23) / Technology (0.08)
# 8                 North_America (0.29) / STEM* (0.19) / Earth_an...
# 9                 Sports (0.59) / North_America (0.35) / Educati...
# 10                Asia* (0.29) / South_Asia (0.25) / North_Ameri...
# 11                Sports (0.39) / Europe* (0.16) / Northern_Euro...
# 12                Sports (0.46) / Europe* (0.15) / Northern_Euro...
# ...
